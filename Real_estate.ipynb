# %% [markdown]
# <a href="https://colab.research.google.com/github/Dax22/Communities-Data-set-Iris-Dataset/blob/main/Real_estate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = "/content/drive/MyDrive/real_estate/Real estate.csv"

# %%
df = pd.read_csv(data)

# %%
df.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %%
df.tail()
# Out:
#       No  X1 transaction date  X2 house age  \
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 409                              4082.01500                                0
# 410                                90.45606                                9
# 411                               390.96960                                7
# 412                               104.81010                                5
# 413                                90.45606                                9
#
#      X5 latitude  X6 longitude  Y house price of unit area
# 409     24.94155     121.50381                        15.4
# 410     24.97433     121.54310                        50.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   No                                      414 non-null    int64
#  1   X1 transaction date                     414 non-null    float64
#  2   X2 house age                            414 non-null    float64
#  3   X3 distance to the nearest MRT station  414 non-null    float64
#  4   X4 number of convenience stores         414 non-null    int64
#  5   X5 latitude                             414 non-null    float64
#  6   X6 longitude                            414 non-null    float64
#  7   Y house price of unit area              414 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 26.0 KB

# %%
df.shape
# Out:
# (414, 8)

# %%
df.describe()
# Out:
#                No  X1 transaction date  X2 house age  \
# count  414.000000           414.000000    414.000000
# mean   207.500000          2013.148971     17.712560
# std    119.655756             0.281967     11.392485
# min      1.000000          2012.667000      0.000000
# 25%    104.250000          2012.917000      9.025000
# 50%    207.500000          2013.167000     16.100000
# 75%    310.750000          2013.417000     28.150000
# max    414.000000          2013.583000     43.800000
#
#        X3 distance to the nearest MRT station  \
# count                              414.000000
# mean                              1083.885689
# std                               1262.109595
# min                                 23.382840
# 25%                                289.324800
# 50%                                492.231300
# 75%                               1454.279000
# max                               6488.021000
#
# ...

# %%
df.columns
# Out:
# Index(['No', 'X1 transaction date', 'X2 house age',
#        'X3 distance to the nearest MRT station',
#        'X4 number of convenience stores', 'X5 latitude', 'X6 longitude',
#        'Y house price of unit area'],
#       dtype='object')

# %%
df.nunique()
# Out:
# No                                        414
# X1 transaction date                        12
# X2 house age                              236
# X3 distance to the nearest MRT station    259
# X4 number of convenience stores            11
# X5 latitude                               234
# X6 longitude                              232
# Y house price of unit area                270
# dtype: int64

# %%
df['X3 distance to the nearest MRT station'].unique()
# Out:
# array([  84.87882,  306.5947 ,  561.9845 ,  390.5684 , 2175.03   ,
#         623.4731 ,  287.6025 , 5512.038  , 1783.18   ,  405.2134 ,
#          90.45606,  492.2313 , 2469.645  , 1164.838  ,  579.2083 ,
#         292.9978 ,  350.8515 ,  368.1363 ,   23.38284, 2275.877  ,
#         279.1726 , 1360.139  ,  480.6977 , 1487.868  ,  383.8624 ,
#         276.449  ,  557.478  ,  451.2438 , 4519.69   ,  769.4034 ,
#         488.5727 ,  323.655  ,  205.367  , 4079.418  , 1935.009  ,
#         577.9615 ,  289.3248 , 4082.015  , 4066.587  ,  519.4617 ,
#         512.7871 ,  533.4762 ,  488.8193 ,  463.9623 ,  640.7391 ,
#        4605.749  , 4510.359  ,  512.5487 , 1758.406  , 1438.579  ,
#        1160.632  ,  371.2495 ,   56.47425,  336.0532 , 1931.207  ,
#         259.6607 , 2175.877  ,  995.7554 ,  123.7429 ,  193.5845 ,
#         104.8101 ,  464.223  ,  424.5442 ,  379.5575 ,  616.4004 ,
#        2185.128  ,  552.4371 , 1414.837  ,  377.7956 ,  150.9347 ,
# ...

# %%
df.isnull().sum()
# Out:
# No                                        0
# X1 transaction date                       0
# X2 house age                              0
# X3 distance to the nearest MRT station    0
# X4 number of convenience stores           0
# X5 latitude                               0
# X6 longitude                              0
# Y house price of unit area                0
# dtype: int64

# %%
df.hist(figsize=(12,8), bins=20)
# Out:
# array([[<Axes: title={'center': 'No'}>,
#         <Axes: title={'center': 'X1 transaction date'}>,
#         <Axes: title={'center': 'X2 house age'}>],
#        [<Axes: title={'center': 'X3 distance to the nearest MRT station'}>,
#         <Axes: title={'center': 'X4 number of convenience stores'}>,
#         <Axes: title={'center': 'X5 latitude'}>],
#        [<Axes: title={'center': 'X6 longitude'}>,
#         <Axes: title={'center': 'Y house price of unit area'}>, <Axes: >]],
#       dtype=object)

# %%
data = df.drop(['No'], axis=1)
data.head()
# Out:
#    X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# 0             2012.917          32.0                                84.87882
# 1             2012.917          19.5                               306.59470
# 2             2013.583          13.3                               561.98450
# 3             2013.500          13.3                               561.98450
# 4             2012.833           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245
#
#    Y house price of unit area
# 0                        37.9
# 1                        42.2
# 2                        47.3
# ...

# %%
correlation_matrix = data.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
sns.heatmap(data.corr())
# Out:
# <Axes: >

# %%
#Normalize the data
from sklearn.preprocessing import StandardScaler
col_normalize = ['X3 distance to the nearest MRT station', 'X4 number of convenience stores', 	'X5 latitude', 	'X6 longitude']
scaler = StandardScaler()
data[col_normalize] = scaler.fit_transform(data[col_normalize])

# %%
data.head()
# Out:
#    X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# 0            -0.823683      1.255628                               -0.792495
# 1            -0.823683      0.157086                               -0.616612
# 2             1.541151     -0.387791                               -0.414015
# 3             1.246435     -0.387791                               -0.414015
# 4            -1.121951     -1.117223                               -0.549997
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                         2.007407     1.125430      0.448762
# 1                         1.667503     0.912444      0.401139
# 2                         0.307885     1.486860      0.688183
# 3                         0.307885     1.486860      0.688183
# 4                         0.307885     0.834188      0.592937
#
#    Y house price of unit area
# 0                        37.9
# 1                        42.2
# 2                        47.3
# ...

# %%
X = data.drop(['Y house price of unit area'], axis=1).copy()
y = data['Y house price of unit area'].copy()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)
print(y_pred)
# Out:
# [40.09548022 12.83819172 42.00966923 12.64733002 42.44343803 39.83198984
#  40.55595745 33.86023762 49.37328265 45.87031976 45.86310332 40.64517161
#  39.50676203 40.04955455 47.11860745 38.13995857 40.08417262 41.12540438
#  40.83964717 42.37860913 49.70003677 31.08231285 39.67622569 45.52764709
#  46.18872415 43.43143246 46.35880414 26.20749681 48.13688227 21.53997799
#  44.8104349  34.94131598 42.6644548  38.37379621 43.98018394 32.28477958
#  47.62406077 39.77407301 52.55712201  7.46443039 52.54110472 33.1285138
#  34.22107416 49.59242876 15.37567885 43.36042455 42.40643117 12.9983919
#  33.99155573 48.50179814 53.67150141 38.73047082 47.73879852 25.42163729
#  30.68691477 34.27187582 48.91161249 40.61983209 43.45816985 32.95307348
#  43.85237072 43.62659423 39.55165632 47.0209757  36.84017788 30.00963218
#   9.66438363 34.92190591 46.16892784 39.83198984 31.0777362  46.14863976
#  44.93807805 30.68551351 40.64359986 36.24180038 31.13625745 13.07226688
# ...

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
print(mse)
# Out:
# 59.522435319028894

# %%
from sklearn.metrics import r2_score
R2 = r2_score(y_test, y_pred)
print(R2)
# Out:
# 0.6573242742217802

# %% [markdown]
# Gradient Boosting Regressor (GBR) is used for various reasons due to its effectiveness in addressing specific challenges in regression task.
# Less Prone to Overfitting:
# By combining weak learners sequentially and introducing regularization parameters like learning rate and max depth, GBR is less prone to overfitting compared to individual decision trees

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV

# %%
#Create a Gradient Bossting Regressor Model
gbr_model = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, criterion='squared_error',
                                    max_depth=8,min_samples_split=5,
                                    min_samples_leaf=5,max_features=3)

# %%
#fit the model
gbr_model.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(criterion='squared_error', max_depth=8,
#                           max_features=3, min_samples_leaf=5,
#                           min_samples_split=5)

# %%
#make predictions on the test data
y_pred = gbr_model.predict(X_test)
print(y_pred)
# Out:
# [71.21795055 16.50631134 44.16555905 18.28105279 32.47515463 42.03472036
#  48.33961961 35.25718096 60.48759961 41.3796118  39.82008554 21.15360741
#  35.93239706 42.23374884 58.93994523 54.59611583 35.73058758 52.02973574
#  41.04936483 40.3589803  50.42458125 26.65620494 33.97911202 52.17092736
#  56.02247602 43.10030499 43.37557038 23.00835959 49.49653954 26.21951735
#  46.99032226 26.53123311 51.85016485 50.23210682 40.60549596 28.66871513
#  47.58938375 24.41110173 54.66432969 15.43353287 51.44788936 33.88119168
#  27.26846831 48.38298268 16.79817235 34.86301229 36.07383658 13.14441782
#  27.71758796 52.68788989 60.82683417 34.35290384 49.9292672  16.97557822
#  27.08091215 37.10918905 54.27904195 37.44193914 42.60293413 24.77122702
#  43.3747557  55.94304314 39.79090501 49.63796731 39.85119302 23.52303725
#  16.44574442 22.6393944  53.04961112 42.03472036 22.61362691 50.8872006
#  49.3376771  24.8237546  37.78538622 30.34677569 27.86417037 13.48724219
# ...

# %%
#calculate the Mean Square Error
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 55.76658315867128

# %%
R2 = r2_score(y_test, y_pred)
print(f'R2 score: {R2}')
# Out:
# R2 score: 0.678947034750108
